# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !pip install tensorflow-hub

# %%
# !pip install tensorflow-datasets==1.0.2
# Out:
# ...
#      |████████████████████████████████| 686kB 2.8MB/s
# ...
#   Found existing installation: tensorflow-datasets 2.1.0
#     Uninstalling tensorflow-datasets-2.1.0:
#       Successfully uninstalled tensorflow-datasets-2.1.0
# ...

# %%
# !pip install tqdm==4.31.1

# %%
# !pip install bert-tensorflow==1.0.1
# Out:
# ...
#      |████████████████████████████████| 71kB 2.4MB/s
# ...

# %%
# !pip install bunch
# Out:
# ...
#   Created wheel for bunch: filename=bunch-1.0.1-cp36-none-any.whl size=7076 sha256=8db6dfea7dbc04aa1cbf818ce7511bb88454df1aaac9d82be6233b413fa42ea9
#   Stored in directory: /root/.cache/pip/wheels/56/0f/19/fbbf81e5764e6d8b74501c4357a88c14c94466ec777c03734c
# Successfully built bunch
# ...

# %%
# !pip install rouge==0.3.2

# %%
# !pip install pyyaml

# %%
# !unzip /content/bert-summarization-master.zip
# Out:
# Archive:  /content/bert-summarization-master.zip
# 2302fc8c4117070d234b21e02e51e20dd66c4f6f
#    creating: bert-summarization-master/
#   inflating: bert-summarization-master/.gitignore
#   inflating: bert-summarization-master/README.md
#   inflating: bert-summarization-master/arguments.py
#   inflating: bert-summarization-master/config.py
#    creating: bert-summarization-master/data/
#  extracting: bert-summarization-master/data/__init__.py
#   inflating: bert-summarization-master/data/load.py
#    creating: bert-summarization-master/layers/
#   inflating: bert-summarization-master/layers/bert.py
#   inflating: bert-summarization-master/layers/normalization.py
#   inflating: bert-summarization-master/layers/transformer.py
#    creating: bert-summarization-master/models/
#  extracting: bert-summarization-master/models/__init__.py
#   inflating: bert-summarization-master/models/abstractive_summarizer.py
#   inflating: bert-summarization-master/models/transformer.py
# ...

# %%
cd /content/bert-summarization-master
# Out:
# /content/bert-summarization-master

# %%
# %run /content/bert-summarization-master/data/load.py
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# WARNING:tensorflow:From /content/bert-summarization-master/ops/tokenization.py:26: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# WARNING:tensorflow:From /content/bert-summarization-master/ops/tokenization.py:26: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/bert/tokenization.py:125: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/bert/tokenization.py:125: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.

# %%
# %run train.py
# Out:
# WARNING:tensorflow:From /content/bert-summarization-master/train.py:44: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# WARNING:tensorflow:From /content/bert-summarization-master/train.py:44: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# WARNING:tensorflow:From /content/bert-summarization-master/train.py:44: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
# WARNING:tensorflow:From /content/bert-summarization-master/train.py:44: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
# WARNING:tensorflow:From /content/bert-summarization-master/train.py:45: The name tf.enable_resource_variables is deprecated. Please use tf.compat.v1.enable_resource_variables instead.
# ...

# %%
# !zip -r /content/bert_sum.zip /content/bert-summarization-master
# Out:
#   adding: content/bert-summarization-master/ (stored 0%)
#   adding: content/bert-summarization-master/.gitignore (deflated 47%)
#   adding: content/bert-summarization-master/requirements.txt (deflated 21%)
#   adding: content/bert-summarization-master/models/ (stored 0%)
#   adding: content/bert-summarization-master/models/transformer.py (deflated 64%)
#   adding: content/bert-summarization-master/models/__pycache__/ (stored 0%)
#   adding: content/bert-summarization-master/models/__pycache__/abstractive_summarizer.cpython-36.pyc (deflated 52%)
#   adding: content/bert-summarization-master/models/__pycache__/__init__.cpython-36.pyc (deflated 21%)
#   adding: content/bert-summarization-master/models/__init__.py (stored 0%)
#   adding: content/bert-summarization-master/models/abstractive_summarizer.py (deflated 80%)
#   adding: content/bert-summarization-master/README.md (deflated 59%)
#   adding: content/bert-summarization-master/train.py (deflated 67%)
# ...
